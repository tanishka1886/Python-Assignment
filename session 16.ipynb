# %% [markdown]
# ### 1.Use iter() and next() to manually loop through a list of 5 trending movies from BookMyShow and print each movie name one by one.

# %%
movies = [
    "Welcome to the jungle",
    "Coktail 2",
    "Bhoot bangla",
    "Chand mera dil",
    "Housefull 5"
]

movie_iterator = iter(movies)

print(next(movie_iterator))
print(next(movie_iterator))
print(next(movie_iterator))
print(next(movie_iterator))
print(next(movie_iterator))
# Out:
# Welcome to the jungle
# Coktail 2
# Bhoot bangla
# Chand mera dil
# Housefull 5

# %% [markdown]
# ### 2.Create a playlist of 6 songs (as a list of strings) and use enumerate() to print each song with its position like Spotify's tracklist (e.g., '1. Kesariya').

# %%
songs = [
    "Kesariya",
    "Apna Bana Le",
    "Tum Hi Ho",
    "Heeriye",
    "Chaleya",
    "Pasoori"
]

for i, song in enumerate(songs, start=1):
    print(i, ".", song, sep="")
# Out:
# 1.Kesariya
# 2.Apna Bana Le
# 3.Tum Hi Ho
# 4.Heeriye
# 5.Chaleya
# 6.Pasoori

# %% [markdown]
# ### 3.Given two lists — one of food items and one of prices — use zip() to print each food item with its price like a Zomato menu (e.g., 'Pizza - ₹250').

# %%
foods = ["Pizza", "Burger", "Pasta", "Sandwich"]
prices = [250, 180, 220, 150]

for food, price in zip(foods, prices):
    print(f"{food} - ₹{price}")
# Out:
# Pizza - ₹250
# Burger - ₹180
# Pasta - ₹220
# Sandwich - ₹150

# %% [markdown]
# ### 4.Write a generator function called insta_posts_generator(posts) that takes a list of Instagram post captions and yields one caption at a time. Use next() to get and print the next post caption each time until all captions are printed.
#
# ### Hint: Use the yield keyword inside your function and handle StopIteration when all posts are done.

# %%
def insta_posts_generator(posts):
    for post in posts:
        yield post

captions = [
    "Enjoying the sunset!",
    "Travel diaries",
    "Coffee time",
    "Weekend vibes"
]

post_generator = insta_posts_generator(captions)

try:
    while True:
        print(next(post_generator))
except StopIteration:
    print("No more posts.")
# Out:
# Enjoying the sunset!
# Travel diaries
# Coffee time
# Weekend vibes
# No more posts.

# %% [markdown]
# ### 5.Build a generator function called cashback_generator(transactions) that takes a list of Paytm transaction amounts and yields 5% cashback for each transaction. Print out the cashback values for all transactions.

# %%
def cashback_generator(transactions):
    for amount in transactions:
        yield amount * 0.05

transactions = [500, 1200, 800, 3500]

for i in cashback_generator(transactions):
    print(f"Cashback: ₹{i}")
# Out:
# Cashback: ₹25.0
# Cashback: ₹60.0
# Cashback: ₹40.0
# Cashback: ₹175.0
