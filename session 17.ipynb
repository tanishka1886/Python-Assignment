# %% [markdown]
# ### 1.Use the math module to calculate the square root, factorial, and value of pi for given numbers, and print each result.

# %%
import math
print(math.sqrt(2))
print(math.factorial(5))
print(math.pi)
# Out:
# 1.4142135623730951
# 120
# 3.141592653589793

# %% [markdown]
# ### 2.Write a script that lists all files in your current directory using the os module, and prints only those files with a .jpg or .png extension.
#
# ### Hint: Use os.listdir() and string methods to filter file names.

# %%
import os

files = os.listdir()
print(files)
print("Image Files:")

for file in files:
    if file.endswith(".jpg") or file.endswith(".png"):
        print(file)
else:
        print("There is no jpg or png file found...")
# Out:
# ['function.ipynb', 'ipl_scores.csv', 'myplaylist.txt', 'score.txt', 'session - 1.ipynb', 'session - 12.ipynb', 'session - 14.ipynb', 'session - 15.ipynb', 'session - 16.ipynb', 'session - 17.ipynb', 'session -13.ipynb', 'session 2.ipynb', 'session 4.ipynb', 'session 5.ipynb', 'session 6.ipynb', 'session 7.ipynb', 'session 9.ipynb', 'session-8.ipynb', 'session6.ipynb', 'sesssion 3.ipynb', 'user_profile.json', 'user_profile.txt']
# Image Files:
# There is no jpg or png file found...

# %% [markdown]
# ### 3.Create a Python program that accepts a date in 'YYYY-MM-DD' format from the user and displays the day of the week using the datetime module.

# %%
from datetime import datetime

date = input("Enter a date (YYYY-MM-DD): ")

d = datetime.strptime(date, "%Y-%m-%d")
print("Day of the week:", d.strftime("%A"))
# Out:
# Day of the week: Friday

# %% [markdown]
# ### 4.Build a simple custom module named insta_utils.py with a function format_follower_count(n) that returns '1.5K' for 1500 and '2.3M' for 2300000. Import and use this function in another script to display formatted counts for 3 sample numbers.

# %%
def format_follower_count(n):
    if n >= 1_000_000:
        return f"{n / 1_000_000:.1f}M"
    elif n >= 1_000:
        return f"{n / 1_000:.1f}K"
    else:
        return str(n)

# %%
from insta_utils import 
format_follower_count

sample_counts = [950, 1500, 2300000]

for count in sample_counts:
    print(f"{count} -> {format_follower_count(count)}")
# Out:
#   Cell In[10], line 1
#     from insta_utils import
#                             ^
# SyntaxError: Expected one or more names after 'import'
